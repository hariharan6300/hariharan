# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %%
data=pd.read_excel('a.xlsx',index_col=0)

# %%
data
# Out:
#              Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       IN-2013-27828 2013-08-26 2013-08-30  Standard Class    VT-21700
# 2       IN-2013-27828 2013-08-26 2013-08-30  Standard Class    VT-21700
# 3       IN-2013-27828 2013-08-26 2013-08-30  Standard Class    VT-21700
# 4       IN-2013-27828 2013-08-26 2013-08-30  Standard Class    VT-21700
# 5       IN-2014-63178 2014-06-24 2014-06-30  Standard Class    SO-20335
# ...               ...        ...        ...             ...         ...
# 10996   IN-2013-82673 2013-09-10 2013-09-14  Standard Class    EM-13810
# 10997   IN-2013-82673 2013-09-10 2013-09-14  Standard Class    EM-13810
# 10998   IN-2013-82673 2013-09-10 2013-09-14  Standard Class    EM-13810
# 10999   ID-2012-83604 2012-08-28 2012-08-28        Same Day    PO-19195
# 11000   ID-2012-83604 2012-08-28 2012-08-28        Same Day    PO-19195
#
#            Customer Name      Segment        City             State  \
# Row ID
# ...

# %%
sns.kdeplot(data["Sales"])

# %%
np.unique(data["Ship Mode"])
# Out:
# array(['First Class', 'Same Day', 'Second Class', 'Standard Class'],
#       dtype=object)
